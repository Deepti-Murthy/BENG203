# %%
import pandas as pd

cancer_df = pd.read_csv("C:/Users/noapo/Downloads/pnas_tpm_96_nodup.txt", sep="\t", header=None)
cancer_df.set_index(cancer_df.columns[0], inplace=True)
cancer_df.columns = [f'C{i+1}' for i in range(cancer_df.shape[1])]
cancer_df.head()
# Out:
#                         C1         C2         C3         C4         C5  \
# 0
# ENSG00000000003   7.071605  60.610797  58.255903  29.917356  24.500322
# ENSG00000000005  13.279391  47.424080  60.455497   6.482332  53.675826
# ENSG00000000419   0.000000   0.000000  23.040206   8.646690  20.456404
# ENSG00000000457   6.212355   2.218590  12.120963   6.065120  16.142519
# ENSG00000000460  34.038592  35.828348  55.926653  10.494273  14.482668
#
#                         C6         C7         C8         C9        C10  ...  \
# 0                                                                       ...
# ENSG00000000003  25.311091  37.394452  15.354658  24.839014  24.591295  ...
# ENSG00000000005  31.686900  32.409716   0.000000  48.976056  46.178684  ...
# ENSG00000000419  42.266702  21.615428  11.538256  18.665274  76.996356  ...
# ENSG00000000457  37.059356   7.580945   0.000000   0.000000  21.603278  ...
# ENSG00000000460  19.236768  13.117055   4.667898  18.877984  12.459809  ...
#
#                        C87        C88         C89        C90        C91  \
# 0
# ENSG00000000003  14.134044  10.803910    6.068982  12.714350  15.983392
# ENSG00000000005   0.000000  12.172853  136.759411  28.650721   0.000000
# ENSG00000000419  79.657691   8.118597    0.000000   0.000000   0.000000
# ENSG00000000457  18.624986  15.660412   33.988677   0.000000  36.858404
# ENSG00000000460  17.903438  19.706680   23.062537   1.932615  28.344382
#
#                         C92        C93        C94         C95        C96
# 0
# ENSG00000000003    0.000000  38.189128  15.608352   51.519267  30.805593
# ENSG00000000005    0.000000   5.976111   6.280734  241.863225   0.000000
# ENSG00000000419  179.178412  15.942897   0.000000    0.000000   0.000000
# ENSG00000000457   83.788404  18.172309   2.938248   14.547636  10.148436
# ENSG00000000460    3.020339  27.411791   1.694651    3.729079   7.804221
#
# [5 rows x 96 columns]

# %%
oncogenes_df = pd.read_csv("C:/Users/noapo/Downloads/cancerGeneList.tsv", sep="\t")
oncogenes_df.head()
# Out:
#   Hugo Symbol  Entrez Gene ID   GRCh37 Isoform   GRCh37 RefSeq  \
# 0        ABL1              25  ENST00000318560     NM_005157.4
# 1        AKT1             207  ENST00000349310  NM_001014431.1
# 2         ALK             238  ENST00000389048     NM_004304.4
# 3       AMER1          139285  ENST00000330258     NM_152424.3
# 4         APC             324  ENST00000257430     NM_000038.5
#
#     GRCh38 Isoform   GRCh38 RefSeq Is Oncogene Is Tumor Suppressor Gene  \
# 0  ENST00000318560     NM_005157.4         Yes                       No
# 1  ENST00000349310  NM_001014431.1         Yes                       No
# 2  ENST00000389048     NM_004304.4         Yes                       No
# 3  ENST00000374869     NM_152424.3          No                      Yes
# 4  ENST00000257430     NM_000038.5          No                      Yes
#
#    # of occurrence within resources (Column J-P) OncoKB Annotated MSK-IMPACT  \
# 0                                              7              Yes        Yes
# 1                                              7              Yes        Yes
# 2                                              7              Yes        Yes
# 3                                              7              Yes        Yes
# 4                                              7              Yes        Yes
#
#   MSK-HEME FOUNDATION ONE FOUNDATION ONE HEME Vogelstein COSMIC CGC (v99)  \
# 0      Yes            Yes                 Yes        Yes              Yes
# 1      Yes            Yes                 Yes        Yes              Yes
# 2      Yes            Yes                 Yes        Yes              Yes
# 3      Yes            Yes                 Yes        Yes              Yes
# 4      Yes            Yes                 Yes        Yes              Yes
#
#                             Gene Aliases
# 0                       ABL, JTK7, c-ABL
# 1        AKT, PKB, PRKBA, RAC, RAC-alpha
# 2                                  CD246
# 3  FAM123B, FLJ39827, RP11-403E24.2, WTX
# 4                         DP2.5, PPP1R46

# %%
from pybiomart import Dataset

dataset = Dataset(name='hsapiens_gene_ensembl', host='http://www.ensembl.org')
mapping_df = dataset.query(attributes=['ensembl_gene_id', 'hgnc_symbol'])
mapping_df.columns = ['Gene stable ID', 'HGNC symbol']
mapping_df = mapping_df[mapping_df['HGNC symbol'] != '']

ensg_to_symbol = dict(zip(mapping_df['Gene stable ID'], mapping_df['HGNC symbol']))

cancer_df['gene_symbol'] = cancer_df.index.map(ensg_to_symbol)
cancer_df = cancer_df[cancer_df['gene_symbol'].notnull()]
cancer_df.set_index('gene_symbol', inplace=True)
cancer_df.head()
# Out:
#                     C1         C2         C3         C4         C5         C6  \
# gene_symbol
# TSPAN6        7.071605  60.610797  58.255903  29.917356  24.500322  25.311091
# TNMD         13.279391  47.424080  60.455497   6.482332  53.675826  31.686900
# DPM1          0.000000   0.000000  23.040206   8.646690  20.456404  42.266702
# SCYL3         6.212355   2.218590  12.120963   6.065120  16.142519  37.059356
# FIRRM        34.038592  35.828348  55.926653  10.494273  14.482668  19.236768
#
#                     C7         C8         C9        C10  ...        C87  \
# gene_symbol                                              ...
# TSPAN6       37.394452  15.354658  24.839014  24.591295  ...  14.134044
# TNMD         32.409716   0.000000  48.976056  46.178684  ...   0.000000
# DPM1         21.615428  11.538256  18.665274  76.996356  ...  79.657691
# SCYL3         7.580945   0.000000   0.000000  21.603278  ...  18.624986
# FIRRM        13.117055   4.667898  18.877984  12.459809  ...  17.903438
#
#                    C88         C89        C90        C91         C92  \
# gene_symbol
# TSPAN6       10.803910    6.068982  12.714350  15.983392    0.000000
# TNMD         12.172853  136.759411  28.650721   0.000000    0.000000
# DPM1          8.118597    0.000000   0.000000   0.000000  179.178412
# SCYL3        15.660412   33.988677   0.000000  36.858404   83.788404
# FIRRM        19.706680   23.062537   1.932615  28.344382    3.020339
#
#                    C93        C94         C95        C96
# gene_symbol
# TSPAN6       38.189128  15.608352   51.519267  30.805593
# TNMD          5.976111   6.280734  241.863225   0.000000
# DPM1         15.942897   0.000000    0.000000   0.000000
# SCYL3        18.172309   2.938248   14.547636  10.148436
# FIRRM        27.411791   1.694651    3.729079   7.804221
#
# [5 rows x 96 columns]

# %%
oncogene_genes = oncogenes_df['Hugo Symbol'].tolist()
filtered_df = cancer_df.loc[cancer_df.index.intersection(oncogene_genes)]
filtered_df.head()
# Out:
#                     C1         C2         C3         C4         C5         C6  \
# gene_symbol
# RAD52        17.859037   7.289047  26.548476  24.908245  11.785623  15.219543
# LASP1         7.569685   2.162662   0.000000   2.956112   3.496796  14.450052
# RECQL         2.829515  36.377709   7.360913  33.149458  22.874028   3.375854
# UPF1         21.131216   7.102583  11.317831  15.776187   7.177581  22.245309
# HOXA11        9.267368   0.000000   0.000000  45.238641  10.702592   5.528382
#
#                     C7        C8         C9        C10  ...        C87  \
# gene_symbol                                             ...
# RAD52         9.340032  0.000000  16.130539   8.872038  ...  33.145289
# LASP1         5.542378  0.000000  23.929669   2.632335  ...  12.103647
# RECQL         6.905723  3.686256  29.816021   9.839556  ...   5.655363
# UPF1         10.617951  1.619381  11.788423   6.483809  ...  17.390900
# HOXA11        5.654491  0.000000   0.000000  24.170248  ...   9.261362
#
#                    C88       C89        C90        C91        C92        C93  \
# gene_symbol
# RAD52         2.338699  3.284347   0.000000   2.883241  17.205119   2.296310
# LASP1         2.775569  0.000000   4.899553  22.241913  45.942857  14.988943
# RECQL         5.187478  0.000000  45.785793   3.197666   0.000000   5.093456
# UPF1         22.788714  0.000000   2.681841   4.214226   0.000000   5.593918
# HOXA11        8.495142  0.000000   0.000000   0.000000   0.000000   8.341169
#
#                    C94        C95        C96
# gene_symbol
# RAD52        26.546970   7.965901  11.114031
# LASP1         4.296268   0.000000   3.297535
# RECQL        26.765437   0.000000   9.244532
# UPF1          2.351624   5.174748   5.414859
# HOXA11        0.000000  19.290348   0.000000
#
# [5 rows x 96 columns]

# %%
metadata_df = pd.read_csv("C:/Users/noapo/Downloads/pnas_patient_info.csv")

column_names = [f"C{i+1}" for i in range(len(metadata_df))]
recur_statuses = metadata_df['recurStatus'].tolist()
new_column_names = [f"{name}_{status}" for name, status in zip(column_names, recur_statuses)]

filtered_df.columns = new_column_names
filtered_df.head()
# Out:
#                   C1_R       C2_R       C3_R       C4_R       C5_R       C6_R  \
# gene_symbol
# RAD52        17.859037   7.289047  26.548476  24.908245  11.785623  15.219543
# LASP1         7.569685   2.162662   0.000000   2.956112   3.496796  14.450052
# RECQL         2.829515  36.377709   7.360913  33.149458  22.874028   3.375854
# UPF1         21.131216   7.102583  11.317831  15.776187   7.177581  22.245309
# HOXA11        9.267368   0.000000   0.000000  45.238641  10.702592   5.528382
#
#                   C7_R      C8_R       C9_R      C10_R  ...      C87_N  \
# gene_symbol                                             ...
# RAD52         9.340032  0.000000  16.130539   8.872038  ...  33.145289
# LASP1         5.542378  0.000000  23.929669   2.632335  ...  12.103647
# RECQL         6.905723  3.686256  29.816021   9.839556  ...   5.655363
# UPF1         10.617951  1.619381  11.788423   6.483809  ...  17.390900
# HOXA11        5.654491  0.000000   0.000000  24.170248  ...   9.261362
#
#                  C88_N     C89_N      C90_N      C91_N      C92_N      C93_N  \
# gene_symbol
# RAD52         2.338699  3.284347   0.000000   2.883241  17.205119   2.296310
# LASP1         2.775569  0.000000   4.899553  22.241913  45.942857  14.988943
# RECQL         5.187478  0.000000  45.785793   3.197666   0.000000   5.093456
# UPF1         22.788714  0.000000   2.681841   4.214226   0.000000   5.593918
# HOXA11        8.495142  0.000000   0.000000   0.000000   0.000000   8.341169
#
#                  C94_N      C95_N      C96_N
# gene_symbol
# RAD52        26.546970   7.965901  11.114031
# LASP1         4.296268   0.000000   3.297535
# RECQL        26.765437   0.000000   9.244532
# UPF1          2.351624   5.174748   5.414859
# HOXA11        0.000000  19.290348   0.000000
#
# [5 rows x 96 columns]

# %%
import numpy as np
from sklearn.decomposition import PCA

# PCA to get the top 100 genes
X = cancer_df.T 

# PCA
pca = PCA()
pca.fit(X)

loadings = pca.components_.T  

# importance vals
k = 2
importance_scores = np.sum(loadings[:, :k]**2, axis=1)

# Get top 100 genes
n_genes = min(100, cancer_df.shape[0])
top_100_genes = cancer_df.index[np.argsort(importance_scores)[::-1][:n_genes]]

print("Top 100 genes:", top_100_genes.tolist())
# Out:
# Top 100 genes: ['HBB', 'MT-TP', 'MT-CYB', 'MT-RNR2', 'MT-ND3', 'MT-ND5', 'MT-ND4', 'MT-ND4L', 'MT-RNR1', 'MT-ND2', 'MT-ND1', 'MT-CO3', 'MT-ND6', 'MT-CO2', 'MT-ATP6', 'MT-ATP8', 'MT-CO1', 'MT-TL1', 'MT-TT', 'MT-TG', 'MT-TH', 'RN7SL2', 'RNA5SP202', 'MT-TS2', 'MIR1911', 'RNA5SP145', 'MT-TL2', 'MT-TF', 'RNA5SP243', 'MT-TI', 'RNU6-411P', 'RNU7-196P', 'MT-TR', 'MT-TW', 'MT-TD', 'MT-TM', 'RNU6-284P', 'RNU6-172P', 'MT-TY', 'PPBP', 'MIR515-1', 'RNU4-2', 'RNU6-1246P', 'RAC2', 'MIR4527', 'MIR548A3', 'MTATP6P1', 'RNU6-627P', 'IGHD1-14', 'MTND1P23', 'SUB1P2', 'KRTAP5-13P', 'KRAS', 'RNU6-826P', 'RNU6-890P', 'MT-TV', 'TIMM8AP1', 'IGHD5-24', 'IFITM3P7', 'RNU1-140P', 'RN7SL130P', 'RPS29P31', 'RNU6-755P', 'FTLP19', 'H2AC17', 'H2AC8', 'RPS26P20', 'RNY3P13', 'RNU6-1108P', 'FTL', 'RPS15AP10', 'SLC4A8-AS1', 'RNU6-39P', 'RN7SL646P', 'HBA1', 'IFNA14', 'RNA5SP220', 'MIR5685', 'S100A9', 'RN7SKP271', 'RNU7-165P', 'RNA5SP467', 'RPL27AP9', 'COX6CP18', 'MTND2P28', 'TPM3P3', 'RNA5SP355', 'MIR8063', 'RNY3', 'RN7SKP55', 'RNA5SP387', 'MT-TE', 'IGHV1-24', 'LYPLA1P2', 'RN7SL477P', 'RNU6-588P', 'PF4', 'RNU1-114P', 'RNA5SP255', 'RPL31P34']

# %%
# keep genes in both the top 100 and cancer gene list (union)
keep_genes = set(top_100_genes).union(set(cancer_df.index))
print("Genes to keep:", keep_genes)
print(len(keep_genes), "genes to keep")

# Filter the combined data to keep only the genes in keep_genes
filtered_df = cancer_df.loc[cancer_df.index.isin(keep_genes)]
# Out:
# Genes to keep: {'SNORA41B', 'TMTC3', 'PSME2P6', 'EFCAB6', 'LINC01877', 'TRAV2', 'OTOP3', 'LINC01166', 'MIR4730', 'FSD1L', 'OLFM4', 'CSE1L', 'ZNF248', 'IRF5P1', 'LILRB1', 'INSYN1', 'ABHD12B', 'MTATP6P16', 'HLCS-AS1', 'ADAD2', 'RHEBP3', 'UNC5B-AS1', 'OR10D4P', 'FTLP3', 'DMAP1', 'ST7-AS2', 'ESPL1', 'USP9YP19', 'KISS1', 'PRR20E', 'LINC01717', 'ZNF507', 'MIR627', 'SNORD116-25', 'POU4F3', 'HKDC1', 'FAM209A', 'FLT3', 'OGFRL1', 'RNA5SP229', 'RPL36AP38', 'OR2B2', 'MYH4', 'RGMB-AS1', 'OR1L1', 'MTHFD2L', 'POC1A', 'ZNF34', 'RMDN1', 'LCN12', 'TRIM31', 'IL21R', 'DKC1', 'RNU1-93P', 'IGLV6-57', 'SRD5A3P1', 'RPL36P19', 'ASPA', 'ROPN1L-AS1', 'MIR6880', 'CALM1', 'BCRP4', 'MIR607', 'FOXE1', 'RNU4-58P', 'RN7SL749P', 'MTCO1P28', 'CITED4', 'INTS15', 'UBDP1', 'RN7SKP227', 'MIR1200', 'ACTN4P2', 'EIF1AY', 'KIF24', 'SI', 'RAF1', 'HTR3B', 'HPSE', 'ZBED2', 'GIMAP5', 'CCDC154', 'ZNF736P1Y', 'RAB2B', 'CNIH3-AS1', 'DEPDC1-AS1', 'RN7SKP271', 'CLDN10-AS1', 'GAPDHP28', 'ZNF277-AS1', 'KYAT1', 'SNRPNP2', 'CIB1', 'RABGEF1P2', 'ADPGK-AS1', 'LINC01702', 'RN7SL865P', 'RNA5SP88', 'PRR35', 'F3', 'PTGR1', 'CACNG1', 'MIR6127', 'RPL17P3', 'CYP4B1', 'PGBD4P2', 'RPL15P17', 'CAMKK1', 'RALYL', 'MTND1P23', 'CLEC4D', 'FAM186A', 'CYP2C8', 'FAM168B', 'SNX19P1', 'MRPL2P1', 'RNA5SP69', 'PTMA', 'LINC02572', 'KRTAP19-6', 'TLK2P1', 'ACER2P1', 'DUX4L16', 'ZNF41', 'NUDCD3', 'CCDC85B', 'LINC01721', 'PRRT4', 'PDZD11', 'LINC02278', 'PPP1R13B-DT', 'RPS27AP20', 'COMMD10', 'ATP1B1', 'NFS1', 'RNU7-23P', 'SCGB1D1', 'RN7SL812P', 'ELK2AP', 'C17orf49', 'RNU6-1044P', 'TPT1P10', 'SAMD11', 'TUBBP1', 'LINC02587', 'LTF', 'BOLA2', 'LINC02485', 'CLSPN', 'SMIM7P1', 'TBC1D3P1', 'MUC5B', 'DKKL1P1', 'ROPN1L', 'SMU1', 'MIR181B1', 'RPL7P13', 'EPGN', 'EIF3KP1', 'RN7SKP59', 'EPHX2', 'MIR203A', 'CICP4', 'C2CD4D', 'DDX19A-DT', 'SUGP2', 'BOLL', 'OR1A1', 'SVIP', 'C9orf40', 'MIER1', 'CIBAR1P1', 'RN7SKP203', 'CACNA2D2', 'CIRBP', 'SMG7', 'FOXD4L5', 'CLK1', 'SP2-AS1', 'ZNF90P3', 'RNU5A-3P', 'ATP5MC3', 'ANKRD40CL', 'SASS6', 'SNORD114-3', 'TRBV13', 'CRIPTOP6', 'MMADHCP2', 'TPST2P1', 'LINC01892', 'TINCR', 'SERINC1', 'ITGAEP1', 'MICOS10', 'ZMAT2', 'HNRNPA1P42', 'MIR7845', 'SNORD41', 'DMXL1-DT', 'LINC00113', 'SEMA6A-AS2', 'HSPE1P27', 'TMEM225', 'DUSP5P2', 'OR2T12', 'SPINT3', 'CD109-AS1', 'ZMYND19', 'MIR3180-3', 'RPL15P8', 'LINC03034', 'MIR8071-2', 'LRRC46', 'FAAH2', 'HTR2B', 'CFHR4', 'LINC02714', 'TENT5A', 'AQP11', 'FCGR3B', 'POLR1A', 'AWAT1', 'OFD1P2Y', 'SCAND3P1', 'CPA6', 'TRBV10-1', 'CTIF', 'SERTAD1', 'MIR3666', 'HNF4GP1', 'MUS81', 'UFSP2', 'MLYCD', 'FAM41AY1', 'SCARNA3', 'RELA', 'NRCAM', 'RNU6-521P', 'SPCS3', 'LIMK2P1', 'MIR5701-2', 'PRKAA2', 'PHKBP1', 'TTYH2', 'OR5F2P', 'MUC20', 'PCDHAC1', 'NCSTNP1', 'RNF43', 'TEX21P', 'AKAP1-DT', 'PRSS35', 'CDK11B', 'RN7SL411P', 'FGF7P3', 'FGF12-AS3', 'RN7SL205P', 'RPL6P30', 'SUSD2P1', 'MIR6792', 'RAX', 'PAQR9', 'HMGB1P33', 'PSMA6P3', 'SNORD37', 'MIR4472-2', 'COL5A2', 'RNU6-98P', 'AK3P7', 'NUTF2P7', 'RN7SL778P', 'RGL3', 'DUXAP6', 'TPRX1P1', 'RN7SL363P', 'IRAG1', 'RNU6-1099P', 'PHF21A', 'RNU4ATAC7P', 'RPL7L1P8', 'GSTA1', 'FRMPD2', 'LINC02180', 'TWF1P1', 'RNF139', 'NDUFB2', 'TMEM210', 'GYG1P1', 'RNU6-1157P', 'VTA1P2', 'ARHGAP24', 'RNU6V', 'SLC25A6P6', 'KIF18BP1', 'RAB4B', 'TRAV23DV6', 'ELOBP4', 'RN7SKP68', 'TMEM121', 'LINC01833', 'SLC20A2', 'LINC00664', 'MPP1', 'LINC01377', 'FECH', 'YTHDF2', 'NPIPA7', 'ECT2', 'OPN3', 'KLHL6-AS1', 'ZBTB8B', 'MTREX', 'SNORA79B', 'WNT3', 'CRCT1', 'PDIA4', 'RNU6ATAC38P', 'ASB2', 'SLC25A45', 'CHRNA4', 'EMILIN2', 'TUBBP8', 'KRT8P27', 'RNU6-1041P', 'NRK', 'OR56A1', 'MTCYBP12', 'FOXF1', 'HECTD4', 'CBX3P6', 'HOXC8', 'RPL7AP49', 'RPL37P23', 'LINC01727', 'ZNF143', 'MIR298', 'SNF8P1', 'FNTAP2', 'TMSB15C', 'OR5H5P', 'MORN4', 'CHRNB1', 'TREML4', 'RPS11P7', 'ADAM33', 'SYCE2', 'TAAR3P', 'SNORD115-6', 'IPO7P1', 'SLC17A8', 'KLHL17', 'SERHL', 'HCG15', 'LRRC57', 'ZNF780B', 'RNA5SP302', 'MIR4755', 'SGK3', 'RNU6-523P', 'RBMY1A1', 'BNIP3P26', 'ZNF771', 'NUPR2P1', 'GDPD4', 'QSOX1', 'VN1R70P', 'PCDHB3', 'ADSL', 'NAALAD2', 'RPL36AP17', 'LCT-AS1', 'OR2L8', 'ABCA15P', 'LRIT1', 'TME ...
# 40187 genes to keep

# %%
import pandas as pd

filtered_columns = filtered_df.columns.tolist()

metadata_df['base_id'] = [f"C{i+1}" for i in range(len(metadata_df))]
metadata_df['full_id'] = metadata_df['base_id'] + '_' + metadata_df['recurStatus']
metadata_df.set_index('full_id', inplace=True)

aligned_metadata = metadata_df.loc[filtered_df.columns]
aligned_metadata['recurStatus'] = aligned_metadata['recurStatus'].replace({'R': 1, 'N': 0}).astype(int)

metadata_fields = ['fu', 'cancerstage_cat', 'er_cat', 'pr_cat', 'her2_cat', 'recurStatus']
metadata_rows = aligned_metadata[metadata_fields].T

combined_with_metadata = pd.concat([filtered_df, metadata_rows])
combined_with_metadata.tail(10)
# Out:
# C:\Users\noapo\AppData\Local\Temp\ipykernel_31304\2954019559.py:10: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   aligned_metadata['recurStatus'] = aligned_metadata['recurStatus'].replace({'R': 1, 'N': 0}).astype(int)
#                       C1_R     C2_R       C3_R      C4_R      C5_R       C6_R  \
# CENPVL2           0.000000  0.00000   0.000000  0.000000  0.000000   0.000000
# BMS1P21           0.000000  0.00000   0.000000  0.000000  0.000000   0.000000
# HYMAI            22.357146  4.56246  12.463189  6.236364  3.688509  22.863419
# RARRES2P11        0.000000  0.00000   0.000000  0.000000  0.000000   0.000000
# fu                2.000000  3.00000   3.000000  4.000000  2.000000   3.000000
# cancerstage_cat   3.000000  3.00000   2.000000  2.000000  3.000000   3.000000
# er_cat            0.000000  0.00000   0.000000  0.000000  1.000000   1.000000
# pr_cat            0.000000  0.00000   0.000000  0.000000  1.000000   1.000000
# her2_cat          0.000000  0.00000   0.000000  0.000000  0.000000   0.000000
# recurStatus       1.000000  1.00000   1.000000  1.000000  1.000000   1.000000
#
#                       C7_R       C8_R       C9_R  C10_R  ...      C87_N  \
# CENPVL2           0.000000   0.000000   0.000000    0.0  ...   0.000000
# BMS1P21           0.000000   0.000000   0.000000    0.0  ...   0.000000
# HYMAI             7.794987  33.287541  26.924393    0.0  ...  35.109888
# RARRES2P11        0.000000   0.000000  23.273746    0.0  ...   0.000000
# fu               10.000000   2.000000   3.000000    4.0  ...   2.000000
# cancerstage_cat   3.000000   1.000000   1.000000    1.0  ...   2.000000
# er_cat            1.000000   1.000000   1.000000    1.0  ...   0.000000
# pr_cat            1.000000   0.000000   0.000000    0.0  ...   0.000000
# her2_cat          0.000000   0.000000   0.000000    0.0  ...   0.000000
# recurStatus       1.000000   1.000000   1.000000    1.0  ...   0.000000
#
#                    C88_N     C89_N  C90_N  C91_N       C92_N      C93_N  \
# CENPVL2          0.00000  0.000000    0.0    0.0    0.000000   0.000000
# BMS1P21          0.00000  0.000000    0.0    0.0    0.000000   0.000000
# HYMAI            2.92774  8.223135    0.0    0.0   32.307790  14.373377
# RARRES2P11       0.00000  0.000000    0.0    0.0  335.126565   0.000000
# fu               5.00000  3.000000    5.0    2.0    3.000000   2.000000
# cancerstage_cat  2.00000  2.000000    2.0    2.0    2.000000   2.000000
# er_cat           0.00000  1.000000    1.0    1.0    1.000000   1.000000
# pr_cat           0.00000  0.000000    0.0    1.0    1.000000   1.000000
# her2_cat         0.00000  0.000000    0.0    0.0    0.000000   0.000000
# recurStatus      0.00000  0.000000    0.0    0.0    0.000000   0.000000
#
#                      C94_N      C95_N  C96_N
# CENPVL2           0.000000   0.000000    0.0
# BMS1P21           0.000000   0.000000    0.0
# HYMAI            12.084831  46.537173    0.0
# RARRES2P11       20.892525   0.000000    0.0
# fu                3.000000   2.000000    3.0
# cancerstage_cat   2.000000   3.000000    3.0
# er_cat            1.000000   1.000000    1.0
# pr_cat            1.000000   1.000000    1.0
# her2_cat          0.000000   1.000000    1.0
# recurStatus       0.000000   0.000000    0.0
#
# [10 rows x 96 columns]
